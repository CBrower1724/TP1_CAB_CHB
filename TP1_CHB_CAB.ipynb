# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
data=pd.read_csv("train.csv")
# Out:
# <style>.container{width:100% !important;}</style>

# %% [markdown]
# Dropping first column as it is repetitive with the pandas dataframe.

# %%
data=data.drop(["Unnamed: 0"],axis=1)
data.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %% [markdown]
# ### #1 Introduction

# %% [markdown]
# Our data set is about cutsomer airline satisfaction which shows variables that correlate passenger satisfaction.

# %% [markdown]
# ### #2 Code for Data Set Description

# %% [markdown]
# Table 1:

# %%
data.head(10)
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
# 5  111157  Female     Loyal Customer   26  Personal Travel       Eco
# 6   82113    Male     Loyal Customer   47  Personal Travel       Eco
# 7   96462  Female     Loyal Customer   52  Business travel  Business
# 8   79485  Female     Loyal Customer   41  Business travel  Business
# 9   65725    Male  disloyal Customer   20  Business travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# ...

# %%
# Convert the 'Arrival Delay in Minutes' column to numeric, forcing errors to NaN
data['Arrival Delay in Minutes'] = pd.to_numeric(data['Arrival Delay in Minutes'], errors='coerce')
imputation={"Arrival Delay in Minutes":data['Arrival Delay in Minutes'].mean()}

# %%
data=data.fillna(value=imputation)
data.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
# ...

# %% [markdown]
# ### #3 Code for Data Set Summary

# %% [markdown]
# Table 2:

# %%
data.describe().transpose()
# Out:
#                                       count          mean           std   min  \
# id                                 103904.0  64924.210502  37463.812252   1.0
# Age                                103904.0     39.379706     15.114964   7.0
# Flight Distance                    103904.0   1189.448375    997.147281  31.0
# Inflight wifi service              103904.0      2.729683      1.327829   0.0
# Departure/Arrival time convenient  103904.0      3.060296      1.525075   0.0
# Ease of Online booking             103904.0      2.756901      1.398929   0.0
# Gate location                      103904.0      2.976883      1.277621   0.0
# Food and drink                     103904.0      3.202129      1.329533   0.0
# Online boarding                    103904.0      3.250375      1.349509   0.0
# Seat comfort                       103904.0      3.439396      1.319088   0.0
# Inflight entertainment             103904.0      3.358158      1.332991   0.0
# ...

# %% [markdown]
# Table 3:

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    52727
# Male      51177
# Name: count, dtype: int64

# %%
data['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       84923
# disloyal Customer    18981
# Name: count, dtype: int64

# %%
data['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    71655
# Personal Travel    32249
# Name: count, dtype: int64

# %%
data['Class'].value_counts()
# Out:
# Class
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: count, dtype: int64

# %%
data['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %%
data_dict = {
    'Gender': {'Female': 52727, 'Male': 51177},
    'Customer Type': {'Loyal Customer': 84923, 'Disloyal Customer': 18981},
    'Type of Travel': {'Business Travel': 71655, 'Personal Travel': 32249},
    'Class': {'Business': 49665, 'Eco': 46745, 'Eco Plus': 7494},
    'Satisfaction': {'Neutral or Dissatisfied': 58879, 'Satisfied': 45025}}
table3 = pd.DataFrame(columns=['Category', 'Frequency', 'Proportion (%)'])
for key, value in data_dict.items():
    temp_df = pd.DataFrame(list(value.items()), columns=['Category', 'Frequency'])
    temp_df['Proportion (%)'] = (temp_df['Frequency'] / temp_df['Frequency'].sum()) * 100
    temp_df['Category Type'] = key
    table3 = pd.concat([table3, temp_df], ignore_index=True)
table3 = table3[['Category Type', 'Category', 'Frequency', 'Proportion (%)']]
table3
# Out:
#      Category Type                 Category Frequency  Proportion (%)
# 0           Gender                   Female     52727       50.745881
# 1           Gender                     Male     51177       49.254119
# 2    Customer Type           Loyal Customer     84923       81.732176
# 3    Customer Type        Disloyal Customer     18981       18.267824
# 4   Type of Travel          Business Travel     71655       68.962696
# 5   Type of Travel          Personal Travel     32249       31.037304
# 6            Class                 Business     49665       47.798930
# 7            Class                      Eco     46745       44.988643
# 8            Class                 Eco Plus      7494        7.212427
# 9     Satisfaction  Neutral or Dissatisfied     58879       56.666731
# 10    Satisfaction                Satisfied     45025       43.333269

# %% [markdown]
# Table 4:

# %%
numerical_data=data.select_dtypes('number').corr()
corr_matrix=numerical_data.corr()
numerical_data
# Out:
#                                          id       Age  Flight Distance  \
# id                                 1.000000  0.022857         0.095544
# Age                                0.022857  1.000000         0.099461
# Flight Distance                    0.095544  0.099461         1.000000
# Inflight wifi service             -0.021276  0.017859         0.007131
# Departure/Arrival time convenient -0.002110  0.038125        -0.020043
# Ease of Online booking             0.014163  0.024842         0.065717
# Gate location                     -0.000606 -0.001330         0.004793
# Food and drink                     0.001063  0.023000         0.056994
# Online boarding                    0.055477  0.208939         0.214869
# Seat comfort                       0.052903  0.160277         0.157333
# Inflight entertainment             0.002300  0.076444         0.128740
# On-board service                   0.055241  0.057594         0.109526
# ...

# %%
plt.figure(figsize=(16,16))
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %% [markdown]
# ### #4 Code for Data Set Graphical Exploration

# %%
sns.boxplot(y='Age',x='satisfaction',data=data)
plt.title("Boxplot Showing Correlation Between Age and Satisfaction")
plt.show()

# %%
sns.lineplot(y=data['Departure Delay in Minutes'],x=data['satisfaction'])
plt.title("Departure Delay Relative to Satisfaction")
plt.show()

# %%
sns.scatterplot(y='Arrival Delay in Minutes',x='satisfaction',data=data)
plt.title("Comparison Between Arrival Delay and Satisfaction")
plt.show()

# %% [markdown]
# Heatmap for matrix with Inflight factors to see what people care about the most.

# %%
numerical_data1=data[['Inflight wifi service','Food and drink','Seat comfort','On-board service','Leg room service','Inflight service','Cleanliness']].corr()
corr_matrix=numerical_data1.corr()
sns.heatmap(corr_matrix,annot=True)
plt.xticks(rotation=45)
plt.show()
